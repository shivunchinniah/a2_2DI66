# %%
import Entity
import Environment
import RecyclingPoint


from importlib import reload
import numpy as np
import matplotlib.pyplot as plt
import scipy 
from importlib import reload

# %%
Environment = reload(Environment)
Entity = reload(Entity)
RecyclingPoint = reload(RecyclingPoint)

from Entity import *
from Environment import Block
from RecyclingPoint import RecyclingPointEnv

# %%
SPH = 3600
recycling_point = RecyclingPointEnv(customer_multiplier=1.1872)
recycling_point.run(SPH*10)
recycling_point.ledger.records
# Out:
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 10
# Green Free Spaces: 5
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 9.5 Arrival
# 1 2 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 10
# Green Free Spaces: 5
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 9.507146415783938 Entrance
# 1 2 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 10
# Green Free Spaces: 5
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 9.58423180592992 Arrival
# 2 1 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 10
# Green Free Spaces: 5
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 9.592373285964856 Entrance
# 2 1 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 9
# Green Free Spaces: 5
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 9.613636350261517 Overflow
# 2 1 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 10
# Green Free Spaces: 5
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 9.615670303281963 Hall
# 1 2 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 10
# Green Free Spaces: 5
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 9.668463611859838 Arrival
# 3 2 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 10
# Green Free Spaces: 5
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 9.675737895230501 Entrance
# 3 2 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 10
# Green Free Spaces: 5
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 9.752695417789758 Arrival
# 4 1 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 10
# Green Free Spaces: 5
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 9.756557320737409 Entrance
# 4 1 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 9
# Green Free Spaces: 5
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 9.773722575349646 Overflow
# 4 1 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 10
# Green Free Spaces: 5
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 9.808561528233252 Hall
# 3 2 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 10
# Green Free Spaces: 5
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 9.836927223719677 Arrival
# 5 1 deque([0, np.int64(1), np.int64(2), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 10
# Green Free Spaces: 5
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 9.844470488268929 Entrance
# 5 1 deque([np.int64(1), np.int64(2), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 9
# Green Free Spaces: 5
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 9.921159029649596 Arrival
# 6 1 deque([0, np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 9
# Green Free Spaces: 5
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 9.924911052096084 Entrance
# 6 1 deque([np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 9
# Green Free Spaces: 4
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 9.937334951632659 Overflow
# 5 1 deque([np.int64(2), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 10
# Green Free Spaces: 4
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 9.993288834942698 Green
# 6 1 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 10
# Green Free Spaces: 5
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 10.005390835579515 Arrival
# 7 2 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 10
# Green Free Spaces: 5
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 10.013814016172507 Arrival
# 8 2 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 10
# Green Free Spaces: 5
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 10.014210811807791 Entrance
# 7 2 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 10
# Green Free Spaces: 5
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 10.022039797434633 Entrance
# 8 2 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 5
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 10.022237196765499 Arrival
# 9 2 deque([0, np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 5
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 10.029313056961634 Entrance
# 9 2 deque([np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 3
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 10.03066037735849 Arrival
# 10 2 deque([0, np.int64(1), np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 3
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 10.039083557951482 Arrival
# 11 2 deque([0, np.int64(4), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 3
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 10.042176939511021 Hall
# 7 2 deque([np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 10
# Green Free Spaces: 3
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 10.043164528783755 Entrance
# 10 2 deque([np.int64(1), np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 3
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 10.047506738544474 Arrival
# 12 2 deque([0, np.int64(3), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 3
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 10.049427857882156 Entrance
# 11 2 deque([np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 3
# DcDd Free Spaces: 6
# Rest Free Spaces: 3
#
# 10.055929919137466 Arrival
# 13 1 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 3
# DcDd Free Spaces: 6
# Rest Free Spaces: 3
#
# 10.061826604488402 Entrance
# 12 2 deque([np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 6
# Rest Free Spaces: 3
#
# 10.063243011536173 DcDd
# 5 1 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 3
#
# 10.064353099730457 Arrival
# 14 2 deque([0, np.int64(3), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 3
#
# 10.07277628032345 Arrival
# 15 2 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 2
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 3
#
# 10.073138057910496 Entrance
# 13 1 deque([np.int64(1), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 9
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 3
#
# 10.076447260981523 Entrance
# 14 2 deque([np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 1, Free Spaces: 12
# Hall Free Spaces: 8
# Overflow Free Spaces: 9
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 3
#
# 10.080365791887044 Entrance
# 15 2 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 2, Free Spaces: 10
# Hall Free Spaces: 8
# Overflow Free Spaces: 9
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 3
#
# 10.081199460916443 Arrival
# 16 1 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 2, Free Spaces: 10
# Hall Free Spaces: 8
# Overflow Free Spaces: 9
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 3
#
# 10.084399497795612 Green
# 9 2 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 6
# Overflow Free Spaces: 9
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 3
#
# 10.085355978731206 Entrance
# 16 1 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 6
# Overflow Free Spaces: 8
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 3
#
# 10.089622641509434 Arrival
# 17 2 deque([0, np.int64(1), np.int64(2), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 6
# Overflow Free Spaces: 8
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 3
#
# 10.095847338702043 Rest
# 11 2 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 6
# Overflow Free Spaces: 8
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.098045822102426 Arrival
# 18 1 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 6
# Overflow Free Spaces: 8
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.098218465269149 Entrance
# 17 2 deque([np.int64(1), np.int64(2), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 8
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.099423054315722 Overflow
# 16 1 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 9
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.104172143858694 Entrance
# 18 1 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 8
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.106469002695418 Arrival
# 19 2 deque([0, np.int64(1), np.int64(2), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 8
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.108999743948502 Green
# 14 2 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 8
# Green Free Spaces: 3
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.1147905064827 Entrance
# 19 2 deque([np.int64(1), np.int64(2), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 8
# Green Free Spaces: 3
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.11489218328841 Arrival
# 20 1 deque([0, np.int64(3), np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 8
# Green Free Spaces: 3
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.123315363881401 Arrival
# 21 2 deque([0, np.int64(1), np.int64(4), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 8
# Green Free Spaces: 3
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.123371751407902 Entrance
# 20 1 deque([np.int64(3), np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 8
# Green Free Spaces: 2
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.131738544474393 Arrival
# 22 2 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 8
# Green Free Spaces: 2
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.135718034315088 Green
# 12 2 deque([np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 8
# Green Free Spaces: 4
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.136785105227352 Entrance
# 21 2 deque([np.int64(1), np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 0
# Overflow Free Spaces: 8
# Green Free Spaces: 4
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.13964110384213 Entrance
# 22 2 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 1, Free Spaces: 12
# Hall Free Spaces: 0
# Overflow Free Spaces: 8
# Green Free Spaces: 4
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.140161725067387 Arrival
# 23 2 deque([0, np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 1, Free Spaces: 12
# Hall Free Spaces: 0
# Overflow Free Spaces: 8
# Green Free Spaces: 4
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.14042068734024 Overflow
# 18 1 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 1, Free Spaces: 12
# Hall Free Spaces: 0
# Overflow Free Spaces: 9
# Green Free Spaces: 4
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.14197183715142 Hall
# 8 2 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 0
# Overflow Free Spaces: 9
# Green Free Spaces: 4
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.146625482132455 Hall
# 19 2 deque([np.int64(2), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 9
# Green Free Spaces: 4
# DcDd Free Spaces: 5
# Rest Free Spaces: 5
#
# 10.148584905660378 Arrival
# 24 1 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 9
# Green Free Spaces: 4
# DcDd Free Spaces: 5
# Rest Free Spaces: 5
#
# 10.14987827314701 Entrance
# 23 2 deque([np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 9
# Green Free Spaces: 2
# DcDd Free Spaces: 5
# Rest Free Spaces: 5
#
# 10.152667989623074 DcDd
# 19 2 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 9
# Green Free Spaces: 2
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.155770027159992 Overflow
# 13 1 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 10
# Green Free Spaces: 2
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.15700808625337 Arrival
# 25 1 deque([0, np.int64(3), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 10
# Green Free Spaces: 2
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.157294945612252 Entrance
# 24 1 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 9
# Green Free Spaces: 2
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.160326181946628 Entrance
# 25 1 deque([np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 9
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.16228069340776 Hall
# 10 2 deque([np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 9
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 3
#
# 10.165431266846362 Arrival
# 26 1 deque([0, np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 9
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 3
#
# 10.173854447439354 Arrival
# 27 1 deque([0, np.int64(1), np.int64(4), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 9
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 3
#
# 10.175483410116641 Entrance
# 26 1 deque([np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 9
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 2
#
# 10.180839955761796 Entrance
# 27 1 deque([np.int64(1), np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 8
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 2
#
# 10.182277628032345 Arrival
# 28 2 deque([0, np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 8
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 2
#
# 10.190700808625337 Arrival
# 29 2 deque([0, np.int64(4), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 8
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 2
#
# 10.193534718543921 Entrance
# 28 2 deque([np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 1, Free Spaces: 12
# Hall Free Spaces: 4
# Overflow Free Spaces: 8
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 2
#
# 10.199123989218329 Arrival
# 30 2 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 1, Free Spaces: 12
# Hall Free Spaces: 4
# Overflow Free Spaces: 8
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 2
#
# 10.199632095222631 Rest
# 26 1 deque([np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 1, Free Spaces: 12
# Hall Free Spaces: 4
# Overflow Free Spaces: 8
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 3
#
# 10.199713925700177 Entrance
# 29 2 deque([np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 2, Free Spaces: 10
# Hall Free Spaces: 4
# Overflow Free Spaces: 8
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 3
#
# 10.202015244532337 Rest
# 10 2 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 2, Free Spaces: 10
# Hall Free Spaces: 4
# Overflow Free Spaces: 8
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.204496416397735 Entrance
# 30 2 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 3, Free Spaces: 8
# Hall Free Spaces: 4
# Overflow Free Spaces: 8
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.207547169811322 Arrival
# 31 2 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 3, Free Spaces: 8
# Hall Free Spaces: 4
# Overflow Free Spaces: 8
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.215970350404314 Arrival
# 32 2 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 3, Free Spaces: 8
# Hall Free Spaces: 4
# Overflow Free Spaces: 8
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.218498636026661 Green
# 20 1 deque([np.int64(4), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 8
# Green Free Spaces: 0
# DcDd Free Spaces: 7
# Rest Free Spaces: 2
#
# 10.222723161416786 Entrance
# 31 2 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 0
# Overflow Free Spaces: 8
# Green Free Spaces: 0
# DcDd Free Spaces: 7
# Rest Free Spaces: 2
#
# 10.223876610906208 Hall
# 22 2 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 8
# Green Free Spaces: 0
# DcDd Free Spaces: 7
# Rest Free Spaces: 2
#
# 10.224257451614966 Hall
# 15 2 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 8
# Green Free Spaces: 0
# DcDd Free Spaces: 7
# Rest Free Spaces: 2
#
# 10.224364898087039 Overflow
# 27 1 deque([np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 9
# Green Free Spaces: 0
# DcDd Free Spaces: 7
# Rest Free Spaces: 1
#
# 10.224393372275532 Hall
# 21 2 deque([np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 9
# Green Free Spaces: 0
# DcDd Free Spaces: 7
# Rest Free Spaces: 1
#
# 10.224393530997306 Arrival
# 33 2 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 9
# Green Free Spaces: 0
# DcDd Free Spaces: 7
# Rest Free Spaces: 1
#
# 10.225721535583068 Green
# 25 1 deque([np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 9
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 1
#
# 10.228408370636872 Entrance
# 32 2 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 9
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 1
#
# 10.232816711590297 Arrival
# 34 2 deque([0, np.int64(4), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 9
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 1
#
# 10.238121584552362 Entrance
# 33 2 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 0
# Overflow Free Spaces: 9
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 1
#
# 10.24123989218329 Arrival
# 35 2 deque([0, np.int64(3), np.int64(4), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 0
# Overflow Free Spaces: 9
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 1
#
# 10.244780422737852 Rest
# 29 2 deque([np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 9
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 1
#
# 10.245409887626616 Entrance
# 34 2 deque([np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 1, Free Spaces: 12
# Hall Free Spaces: 2
# Overflow Free Spaces: 9
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 1
#
# 10.245503577017434 Green
# 28 2 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 1, Free Spaces: 12
# Hall Free Spaces: 2
# Overflow Free Spaces: 9
# Green Free Spaces: 3
# DcDd Free Spaces: 7
# Rest Free Spaces: 1
#
# 10.249663072776281 Arrival
# 36 2 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 1, Free Spaces: 12
# Hall Free Spaces: 2
# Overflow Free Spaces: 9
# Green Free Spaces: 3
# DcDd Free Spaces: 7
# Rest Free Spaces: 1
#
# 10.251385520674072 Hall
# 30 2 deque([np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 1, Free Spaces: 12
# Hall Free Spaces: 4
# Overflow Free Spaces: 9
# Green Free Spaces: 3
# DcDd Free Spaces: 7
# Rest Free Spaces: 1
#
# 10.25582054223258 Overflow
# 24 1 deque([np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 1, Free Spaces: 12
# Hall Free Spaces: 4
# Overflow Free Spaces: 10
# Green Free Spaces: 3
# DcDd Free Spaces: 7
# Rest Free Spaces: 1
#
# 10.256698066606186 Entrance
# 35 2 deque([np.int64(3), np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 2, Free Spaces: 10
# Hall Free Spaces: 4
# Overflow Free Spaces: 10
# Green Free Spaces: 3
# DcDd Free Spaces: 7
# Rest Free Spaces: 1
#
# 10.258086253369273 Arrival
# 37 2 deque([0, np.int64(3), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 2, Free Spaces: 10
# Hall Free Spaces: 4
# Overflow Free Spaces: 10
# Green Free Spaces: 3
# DcDd Free Spaces: 7
# Rest Free Spaces: 1
#
# 10.26308801444651 Rest
# 20 1 deque([np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 0
#
# 10.26466785078915 Entrance
# 36 2 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 0
#
# 10.266509433962264 Arrival
# 38 2 deque([0, np.int64(3), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 0
#
# 10.269813049725299 Entrance
# 37 2 deque([np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 1, Free Spaces: 12
# Hall Free Spaces: 2
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 0
#
# 10.274932614555258 Arrival
# 39 1 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 1, Free Spaces: 12
# Hall Free Spaces: 2
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 0
#
# 10.275477037083395 Entrance
# 38 2 deque([np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 2, Free Spaces: 10
# Hall Free Spaces: 2
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 0
#
# 10.28335579514825 Arrival
# 40 1 deque([0, np.int64(3), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 2, Free Spaces: 10
# Hall Free Spaces: 2
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 0
#
# 10.28419365799212 Hall
# 32 2 deque([np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 2, Free Spaces: 10
# Hall Free Spaces: 4
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 0
#
# 10.286168785185913 Rest
# 27 1 deque([np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 2, Free Spaces: 10
# Hall Free Spaces: 4
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 1
#
# 10.29096961529152 Entrance
# 39 1 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 3, Free Spaces: 9
# Hall Free Spaces: 4
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 1
#
# 10.291778975741241 Arrival
# 41 1 deque([0, np.int64(1), np.int64(4), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 3, Free Spaces: 9
# Hall Free Spaces: 4
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 1
#
# 10.29435125537562 Rest
# 21 2 deque([np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 3, Free Spaces: 9
# Hall Free Spaces: 4
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 3
#
# 10.295704686203983 Rest
# 34 2 deque([np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 3, Free Spaces: 9
# Hall Free Spaces: 4
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.300202156334233 Arrival
# 42 2 deque([0, np.int64(1), np.int64(2), np.int64(5)])
# External Queue Length: 2
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 3, Free Spaces: 9
# Hall Free Spaces: 4
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.301257537278758 Entrance
# 40 1 deque([np.int64(3), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 4, Free Spaces: 8
# Hall Free Spaces: 4
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.308625336927225 Arrival
# 43 1 deque([0, np.int64(3), np.int64(5)])
# External Queue Length: 2
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 4, Free Spaces: 8
# Hall Free Spaces: 4
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.310412806538674 Entrance
# 41 1 deque([np.int64(1), np.int64(4), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 5, Free Spaces: 7
# Hall Free Spaces: 4
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.311951778496711 Hall
# 31 2 deque([np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 5, Free Spaces: 7
# Hall Free Spaces: 6
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.317048517520217 Arrival
# 44 1 deque([0, np.int64(1), np.int64(2), np.int64(4), np.int64(5)])
# External Queue Length: 2
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 5, Free Spaces: 7
# Hall Free Spaces: 6
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.318733861497579 Entrance
# 42 2 deque([np.int64(1), np.int64(2), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 6, Free Spaces: 5
# Hall Free Spaces: 6
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.32451690892015 Entrance
# 43 1 deque([np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 7, Free Spaces: 4
# Hall Free Spaces: 6
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.325471698113208 Arrival
# 45 2 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 7, Free Spaces: 4
# Hall Free Spaces: 6
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 10.326337433833611 Hall
# 17 2 deque([np.int64(2), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 7, Free Spaces: 4
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 5
# Rest Free Spaces: 5
#
# 10.333756760547786 Green
# 23 2 deque([np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 6, Free Spaces: 6
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 5
# Rest Free Spaces: 5
#
# 10.3338948787062 Arrival
# 46 1 deque([0, np.int64(1), np.int64(2), np.int64(4), np.int64(5)])
# External Queue Length: 2
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 6, Free Spaces: 6
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 5
# Rest Free Spaces: 5
#
# 10.339041588981807 Entrance
# 44 1 deque([np.int64(1), np.int64(2), np.int64(4), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 7, Free Spaces: 5
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 5
# Rest Free Spaces: 5
#
# 10.342318059299192 Arrival
# 47 2 deque([0, np.int64(3), np.int64(4), np.int64(5)])
# External Queue Length: 2
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 7, Free Spaces: 5
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 5
# Rest Free Spaces: 5
#
# 10.34346178443394 Entrance
# 45 2 deque([np.int64(1), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 8, Free Spaces: 3
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 5
# Rest Free Spaces: 5
#
# 10.346733862915888 Green
# 35 2 deque([np.int64(4), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 3, Free Spaces: 10
# Hall Free Spaces: 6
# Overflow Free Spaces: 8
# Green Free Spaces: 0
# DcDd Free Spaces: 5
# Rest Free Spaces: 3
#
# 10.348395925382473 Entrance
# 46 1 deque([np.int64(1), np.int64(2), np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 4, Free Spaces: 9
# Hall Free Spaces: 6
# Overflow Free Spaces: 8
# Green Free Spaces: 0
# DcDd Free Spaces: 5
# Rest Free Spaces: 3
#
# 10.350741239892185 Arrival
# 48 1 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 4, Free Spaces: 9
# Hall Free Spaces: 6
# Overflow Free Spaces: 8
# Green Free Spaces: 0
# DcDd Free Spaces: 5
# Rest Free Spaces: 3
#
# 10.355242557052932 Green
# 40 1 deque([np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 6
# Green Free Spaces: 0
# DcDd Free Spaces: 5
# Rest Free Spaces: 3
#
# 10.355299792583935 Entrance
# 47 2 deque([np.int64(3), np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 1, Free Spaces: 12
# Hall Free Spaces: 4
# Overflow Free Spaces: 6
# Green Free Spaces: 0
# DcDd Free Spaces: 5
# Rest Free Spaces: 3
#
# 10.358415775601365 Entrance
# 48 1 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 2, Free Spaces: 11
# Hall Free Spaces: 4
# Overflow Free Spaces: 6
# Green Free Spaces: 0
# DcDd Free Spaces: 5
# Rest Free Spaces: 3
#
# 10.358676921496766 Overflow
# 39 1 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 2, Free Spaces: 11
# Hall Free Spaces: 4
# Overflow Free Spaces: 7
# Green Free Spaces: 0
# DcDd Free Spaces: 5
# Rest Free Spaces: 3
#
# 10.359164420485177 Arrival
# 49 1 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 2, Free Spaces: 11
# Hall Free Spaces: 4
# Overflow Free Spaces: 7
# Green Free Spaces: 0
# DcDd Free Spaces: 5
# Rest Free Spaces: 3
#
# 10.35959158426317 Overflow
# 44 1 deque([np.int64(2), np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 2, Free Spaces: 11
# Hall Free Spaces: 4
# Overflow Free Spaces: 8
# Green Free Spaces: 0
# DcDd Free Spaces: 4
# Rest Free Spaces: 3
#
# 10.363236600150138 Overflow
# 46 1 deque([np.int64(2), np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 2, Free Spaces: 11
# Hall Free Spaces: 4
# Overflow Free Spaces: 9
# Green Free Spaces: 0
# DcDd Free Spaces: 3
# Rest Free Spaces: 3
#
# 10.363590964400466 Entrance
# 49 1 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 3, Free Spaces: 10
# Hall Free Spaces: 4
# Overflow Free Spaces: 9
# Green Free Spaces: 0
# DcDd Free Spaces: 3
# Rest Free Spaces: 3
#
# 10.367587601078169 Arrival
# 50 1 deque([0, np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 3, Free Spaces: 10
# Hall Free Spaces: 4
# Overflow Free Spaces: 9
# Green Free Spaces: 0
# DcDd Free Spaces: 3
# Rest Free Spaces: 3
#
# 10.37601078167116 Arrival
# 51 1 deque([0, np.int64(1), np.int64(2), np.int64(4), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 3, Free Spaces: 10
# Hall Free Spaces: 4
# Overflow Free Spaces: 9
# Green Free Spaces: 0
# DcDd Free Spaces: 3
# Rest Free Spaces: 3
#
# 10.378133121539998 Entrance
# 50 1 deque([np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 4, Free Spaces: 9
# Hall Free Spaces: 4
# Overflow Free Spaces: 9
# Green Free Spaces: 0
# DcDd Free Spaces: 3
# Rest Free Spaces: 3
#
# 10.384433962264152 Arrival
# 52 1 deque([0, np.int64(3), np.int64(4), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 4, Free Spaces: 9
# Hall Free Spaces: 4
# Overflow Free Spaces: 9
# Green Free Spaces: 0
# DcDd Free Spaces: 3
# Rest Free Spaces: 3
#
# 10.386765287818278 Rest
# 35 2 deque([np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 4, Free Spaces: 9
# Hall Free Spaces: 4
# Overflow Free Spaces: 9
# Green Free Spaces: 0
# DcDd Free Spaces: 3
# Rest Free Spaces: 5
#
# 10.388270656290048 Entrance
# 51 1 deque([np.int64(1), np.int64(2), np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 5, Free Spaces: 8
# Hall Free Spaces: 4
# Overflow Free Spaces: 9
# Green Free Spaces: 0
# DcDd Free Spaces: 3
# Rest Free Spaces: 5
#
# 10.392728590971469 Hall
# 33 2 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 5, Free Spaces: 8
# Hall Free Spaces: 6
# Overflow Free Spaces: 9
# Green Free Spaces: 0
# DcDd Free Spaces: 3
# Rest Free Spaces: 5
#
# 10.392857142857144 Arrival
# 53 2 deque([0, np.int64(4), np.int64(5)])
# External Queue Length: 1
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 5, Free Spaces: 8
# Hall Free Spaces: 6
# Overflow Free Spaces: 9
# Green Free Spaces: 0
# DcDd Free Spaces: 3
# Rest Free Spaces: 5
#
# 10.393163015636027 Entrance
# 52 1 deque([np.int64(3), np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# ...
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 7
# Green Free Spaces: 5
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 16.815650789536125 Overflow
# 702 1 deque([np.int64(2), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 8
# Green Free Spaces: 5
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 16.815679994162082 Entrance
# 707 1 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 7
# Green Free Spaces: 5
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 16.82606132075471 Arrival
# 708 2 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 7
# Green Free Spaces: 5
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 16.832289129330846 Overflow
# 704 1 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 8
# Green Free Spaces: 5
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 16.83961706395695 Entrance
# 708 2 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 6
# Overflow Free Spaces: 8
# Green Free Spaces: 5
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 16.842907681940694 Arrival
# 709 1 deque([0, np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 6
# Overflow Free Spaces: 8
# Green Free Spaces: 5
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 16.850270612497468 Entrance
# 709 1 deque([np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 6
# Overflow Free Spaces: 8
# Green Free Spaces: 4
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 16.859754043126678 Arrival
# 710 2 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 6
# Overflow Free Spaces: 8
# Green Free Spaces: 4
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 16.873224453879512 Entrance
# 710 2 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 8
# Green Free Spaces: 4
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 16.87660040431266 Arrival
# 711 2 deque([0, np.int64(1), np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 8
# Green Free Spaces: 4
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 16.886763917101284 Entrance
# 711 2 deque([np.int64(1), np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 8
# Green Free Spaces: 4
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 16.893446765498645 Arrival
# 712 1 deque([0, np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 2
# Overflow Free Spaces: 8
# Green Free Spaces: 4
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 16.897039720517306 Hall
# 706 2 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 8
# Green Free Spaces: 4
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 16.901226595056208 Overflow
# 707 1 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 4
# Overflow Free Spaces: 9
# Green Free Spaces: 4
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 16.9026034907354 Hall
# 708 2 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 6
# Overflow Free Spaces: 9
# Green Free Spaces: 4
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 16.909611316300555 Entrance
# 712 1 deque([np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 6
# Overflow Free Spaces: 9
# Green Free Spaces: 3
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 16.91029312668463 Arrival
# 713 1 deque([0, np.int64(1), np.int64(2), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 6
# Overflow Free Spaces: 9
# Green Free Spaces: 3
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 16.916327142014257 Entrance
# 713 1 deque([np.int64(1), np.int64(2), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 6
# Overflow Free Spaces: 8
# Green Free Spaces: 3
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 16.920114008481615 Hall
# 711 2 deque([np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 8
# Green Free Spaces: 3
# DcDd Free Spaces: 6
# Rest Free Spaces: 3
#
# 16.920630417960965 Overflow
# 705 1 deque([np.int64(2), np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 9
# Green Free Spaces: 3
# DcDd Free Spaces: 5
# Rest Free Spaces: 3
#
# 16.927139487870612 Arrival
# 714 2 deque([0, np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 9
# Green Free Spaces: 3
# DcDd Free Spaces: 5
# Rest Free Spaces: 3
#
# 16.928314803870805 Overflow
# 713 1 deque([np.int64(2), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 3
# DcDd Free Spaces: 4
# Rest Free Spaces: 3
#
# 16.936225844315718 Green
# 712 1 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 4
# DcDd Free Spaces: 4
# Rest Free Spaces: 3
#
# 16.940384162548746 Entrance
# 714 2 deque([np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 2
# DcDd Free Spaces: 4
# Rest Free Spaces: 3
#
# 16.943985849056595 Arrival
# 715 1 deque([0, np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 2
# DcDd Free Spaces: 4
# Rest Free Spaces: 3
#
# 16.948977525060265 Entrance
# 715 1 deque([np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 8
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 4
# Rest Free Spaces: 3
#
# 16.949386604493554 Hall
# 710 2 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 10
# Green Free Spaces: 1
# DcDd Free Spaces: 4
# Rest Free Spaces: 3
#
# 16.959848761134797 Green
# 714 2 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 10
# Green Free Spaces: 3
# DcDd Free Spaces: 4
# Rest Free Spaces: 3
#
# 16.96083221024258 Arrival
# 716 1 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 10
# Green Free Spaces: 3
# DcDd Free Spaces: 4
# Rest Free Spaces: 3
#
# 16.96882125587072 Entrance
# 716 1 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 9
# Green Free Spaces: 3
# DcDd Free Spaces: 4
# Rest Free Spaces: 3
#
# 16.977678571428562 Arrival
# 717 1 deque([0, np.int64(1), np.int64(2), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 9
# Green Free Spaces: 3
# DcDd Free Spaces: 4
# Rest Free Spaces: 3
#
# 16.979070196788044 Rest
# 711 2 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 9
# Green Free Spaces: 3
# DcDd Free Spaces: 4
# Rest Free Spaces: 5
#
# 16.982025087442295 Entrance
# 717 1 deque([np.int64(1), np.int64(2), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 8
# Green Free Spaces: 3
# DcDd Free Spaces: 4
# Rest Free Spaces: 5
#
# 16.98910981567812 DcDd
# 702 1 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 8
# Green Free Spaces: 3
# DcDd Free Spaces: 5
# Rest Free Spaces: 5
#
# 16.994524932614546 Arrival
# 718 2 deque([0, np.int64(2), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 8
# Green Free Spaces: 3
# DcDd Free Spaces: 5
# Rest Free Spaces: 5
#
# 17.00220179306564 Overflow
# 716 1 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 9
# Green Free Spaces: 3
# DcDd Free Spaces: 5
# Rest Free Spaces: 5
#
# 17.002749268968756 Entrance
# 718 2 deque([np.int64(2), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 9
# Green Free Spaces: 3
# DcDd Free Spaces: 3
# Rest Free Spaces: 5
#
# 17.01137129380053 Arrival
# 719 2 deque([0, np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 9
# Green Free Spaces: 3
# DcDd Free Spaces: 3
# Rest Free Spaces: 5
#
# 17.01441691807821 DcDd
# 718 2 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 0, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 9
# Green Free Spaces: 3
# DcDd Free Spaces: 5
# Rest Free Spaces: 5
#
# 17.019344084549108 Entrance
# 719 2 deque([np.int64(3), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 9
# Green Free Spaces: 1
# DcDd Free Spaces: 5
# Rest Free Spaces: 5
#
# 17.03148864875649 DcDd
# 713 1 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 9
# Green Free Spaces: 1
# DcDd Free Spaces: 6
# Rest Free Spaces: 5
#
# 17.041588129244488 DcDd
# 705 1 deque([np.int64(4), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 9
# Green Free Spaces: 1
# DcDd Free Spaces: 7
# Rest Free Spaces: 4
#
# 17.044099116337485 Green
# 709 1 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 10
# Overflow Free Spaces: 9
# Green Free Spaces: 2
# DcDd Free Spaces: 7
# Rest Free Spaces: 4
#
# 17.049454007841017 Hall
# 699 2 deque([np.int64(2), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 9
# Green Free Spaces: 2
# DcDd Free Spaces: 5
# Rest Free Spaces: 4
#
# 17.059299185463495 Rest
# 705 1 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 9
# Green Free Spaces: 2
# DcDd Free Spaces: 5
# Rest Free Spaces: 5
#
# 17.067265937603597 Overflow
# 717 1 deque([np.int64(2), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 10
# Green Free Spaces: 2
# DcDd Free Spaces: 4
# Rest Free Spaces: 5
#
# 17.204766753831194 DcDd
# 717 1 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 10
# Green Free Spaces: 2
# DcDd Free Spaces: 5
# Rest Free Spaces: 5
#
# 17.220782331825855 Green
# 719 2 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 10
# Green Free Spaces: 4
# DcDd Free Spaces: 5
# Rest Free Spaces: 5
#
# 17.232080588434954 DcDd
# 699 2 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 10
# Green Free Spaces: 4
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 17.285808195892237 Green
# 715 1 deque([np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 10
# Green Free Spaces: 5
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 17.285808195892237
# []
