# %%
import Entity
import Environment
import RecyclingPoint


from importlib import reload
import numpy as np
import matplotlib.pyplot as plt
import scipy 
from importlib import reload

# %%
Environment = reload(Environment)
Entity = reload(Entity)
RecyclingPoint = reload(RecyclingPoint)

from Entity import *
from Environment import Block
from RecyclingPoint import RecyclingPointEnv

# %%
SPH = 3600 # seconds per hour
recycling_point = RecyclingPointEnv(customer_multiplier=1.1872)
recycling_point.run(SPH*10)
recycling_point.ledger.records
# Out:
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 10
# Green Free Spaces: 5
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 9.5 Arrival
# 1 1 deque([0, np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: True, Free Spaces: 1, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 10
# Green Free Spaces: 5
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 9.509421641193123 Entrance
# 1 1 deque([np.int64(1), np.int64(5)])
# External Queue Length: 0
# Entrance In Use: False, Free Spaces: 2, Waiting To Move On: False
# Hall/Overflow Queue Length: 0, Free Spaces: 14
# Hall Free Spaces: 12
# Overflow Free Spaces: 9
# Green Free Spaces: 5
# DcDd Free Spaces: 7
# Rest Free Spaces: 5
#
# 9.537834850368741 Overflow
# 1 1 deque([np.int64(5)])
# External Queue Length: 0
# ...
